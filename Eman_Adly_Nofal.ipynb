# %% [markdown]
# <a href="https://colab.research.google.com/github/Eman-Adly/Eman-Adly/blob/main/Eman_Adly_Nofal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from pathlib import Path
folder_path = "E:/data"
files = os.listdir(folder_path)
print(files)

# %%
from pathlib import Path
path = Path("E:/data")
for file in path.iterdir():
    print(file)

# %%
import os
import shutil
folder_path = "E:/data"
folder_name = os.path.basename(folder_path)
os.makedirs("new_folder", exist_ok=True)
os.rmdir("new_folder")
try:
    files = os.listdir(folder_path)
    print(f"Files in '{folder_name}':", files)
except FileNotFoundError:
    print(f"Error: Directory '{folder_name}' not found.")
new_dir = "new_directory"
os.makedirs(new_dir, exist_ok=True)
#Join paths (os.path.join)
file_path = os.path.join(folder_path,"0001.1999-12-10.farmer.ham.txt")
print(f"Combined path: {file_path}")
current_dir = os.getcwd()
print(f"Current directory: {current_dir}")
new_path = "E:/data"
new_folder_name = os.path.basename(new_path)
print(f"Does '{new_folder_name}' exist? ", os.path.exists(new_path))
print(f"Is '{new_folder_name}' a file? ", os.path.isfile(new_path))
print(f"Is '{new_folder_name}' a directory? ", os.path.isdir(new_path))

# %%
import zipfile
import os
zip_path = "E:/data"
os.makedirs(os.path.dirname(zip_path), exist_ok=True)
files_to_zip = ["E:/data/archive/test/0002.2004-08-01.BG.spam.txt","E:/data/archive/test/0003.2004-08-01.BG.spam.txt",
                "E:/data/archive/test/0004.2004-08-01.BG.spam.txt"]
with zipfile.ZipFile(zip_path, "w", zipfile.ZIP_DEFLATED) as zipf:
    for file in files_to_zip:
        if os.path.exists(file):
            zipf.write(file, os.path.basename(file))
        else:
            print(f"Warning: File {file} not found and will not be added.")
print(f"✔ ZIP file created at: {zip_path}")

# %%
import zipfile
import os
zip_path = "E:/data"
extract_to = "E:/data"
os.makedirs(extract_to, exist_ok=True)
with zipfile.ZipFile(zip_path, "r") as zipf:
    zipf.extractall(extract_to)
print(f"✔ Files extracted to: {extract_to}")

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import re
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
text = """Hey!!! How are you doing?? 😀 NLP is amazing, but sometimes it's challenging...
          Let's clean this text properly, remove stopwords, and make it useful!"""
print("Raw Text:\n", text)
# Out:
# Raw Text:
#  Hey!!! How are you doing?? 😀 NLP is amazing, but sometimes it's challenging...
#           Let's clean this text properly, remove stopwords, and make it useful!

# %%
import re
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Function to clean text
def clean_text(text):
    # Convert text to lowercase
    text = text.lower()

    # Remove punctuation and special characters (including emojis)
    text = re.sub(r'[^\w\s]', '', text)

    # Tokenize text
    words = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    # Lemmatize words
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]

    # Join words back into a single string
    cleaned_text = ' '.join(words)

    return cleaned_text

text = """Hey!!! How are you doing?? 😀 NLP is amazing, but sometimes it's challenging...
          Let's clean this text properly, remove stopwords, and make it useful!"""
cleaned_text = clean_text(text)
print("\nCleaned Text:\n", cleaned_text)
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Cleaned Text:
#  hey nlp amazing sometimes challenging let clean text properly remove stopwords make useful
